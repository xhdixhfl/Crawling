# %% [markdown]
# # library loading

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # function

# %%
# 패턴을 이용하여 저장 값을 리스트로 되돌리는 함수
def make_ls(c,i): # 인덱스 리스트와 순서를 받음
    matches = re.findall(r"'(.*?)'", c[i])
    return list(matches)

def clear_text(sentence):  # 목차 내용 정제 함수
    pattern = r'[\w가-힣]+'
    extracted = re.findall(pattern, sentence)
    result = ' '.join(extracted)
    return result
    
def delete_text(sentence):
    pattern = r'u3000|u000|u00|uf0ab|u2005|'#목차 더보기'
    result = re.sub(pattern, '', sentence)
    return result
    
def split_pn(line): # 페이지 분리 함수
    a = re.sub(r'[^(X|IX|IV|V?I|Ⅱ|Ⅲ)]','', line) # 로마자인지 구분하기 위함
    if line.split(' ')[-1].isnumeric() == True and a == '':
        page = line.split(' ')[-1]  
        line = ' '.join(line.split(' ')[:-1])
    else:
        page = np.NaN
    return line, page

def plus_pandan(pd_l):
    if '총' in pd_l and '각' in pd_l:
        i = pd_l.index('총')
        pd_l[i] = ['총', '각']
        pd_l.remove('각')
    elif '총론' in pd_l and '각론' in pd_l:
        i = pd_l.index('총론')
        pd_l[i] = ['총론', '각론']
        pd_l.remove('각론')
#     elif '총론' in pd_l and '각론' in pd_l and '부록' in pd_l:
#         i = pd_l.index('총론')
#         pd_l[i] = ['총론', '각론', '부록']
    elif '형법총론' in pd_l and '형법각론' in pd_l:
        i = pd_l.index('형법총론')
        pd_l[i] = ['형법총론', '형법각론']
        pd_l.remove('형법각론')
    elif '헌법총론' in pd_l and '헌법각론' in pd_l:
        i = pd_l.index('헌법총론')
        pd_l[i] = ['헌법총론', '헌법각론']
        pd_l.remove('헌법각론')
    else:
        pass
    return pd_l

# %%
# def classification_list2(text, ex): # 판별 요소 설정 함수
#     pd_l,roma_l, ara_l = [],[],[]
#     for idx, line in enumerate(text):
#         a = re.sub(r'[^(X|IX|IV|V?I|Ⅱ|Ⅲ)]','', line)
#         # 숫자 판별
#         if line[0].isnumeric() == True: 
#             if a != '' and 'roma' not in pd_l: # 로마 숫자
#                 roma_l.append(idx) # 위치 저장
#                 pd_l.append('roma')
#             elif a != '' and 'roma' in pd_l: # 로마 숫자
#                 roma_l.append(idx) # 위치 저장
#             elif a == '' and line[1] in ['부', '절','편','강'] and 'num' not in pd_l :
#                 ara_l.append(idx)
#                 pd_l.append('num') # 분류랑 숫자 결합
#             elif a == '' and line[1] in ['부', '절','편','강'] and 'num' in pd_l:
# #                 ara_l.append(idx)
#                 print('') #num,'적용 X')print('num')
#             elif a == '' and line[1] not in ['부', '절','편','강'] and 'ara' not in pd_l :
#                 ara_l.append(idx)
#                 pd_l.append('ara') # 분류랑 숫자 결합
#             elif a == '' and line[1] not in ['부', '절','편','강'] and 'ara' in pd_l:
#                 ara_l.append(idx)
#         elif line[0].isnumeric() != True:   # 포함되는 리스트
#             t = re.sub(r'[^a-zA-Z가-힣]','',line.lower())  # 기록 시에는 line을 기록해야 함
#             b = ex.match(t)
#             if b and b.group() not in pd_l:
#                 pd_l.append(b.group())
# #                 print(b.group(), text)
#             elif b and b.group() in pd_l:
#                 pass
#             else:
#                 pd_l.append('check')
# #                 print(t)      
                
#     return pd_l

# %%
def classification_list2(text, ex): # 판별 요소 설정 함수
    pd_l,ck_l = [],[]
    for idx, line in enumerate(text):
        a = re.sub(r'[^(X|IX|IV|V?I|Ⅱ|Ⅲ)]','', line)
        # 숫자 판별
        if line[0].isnumeric() == True: 
            if a != '' and 'roma' not in pd_l: # 로마 숫자
                ck_l.append('roma') # 위치 저장
                pd_l.append('roma')
            elif a != '' and 'roma' in pd_l: # 로마 숫자
                ck_l.append('roma') # 위치 저장
            elif a == '' and line[1] in ['부', '절','편','강'] and 'num' not in pd_l :
                ck_l.append('num')
                pd_l.append('num') # 분류랑 숫자 결합
            elif a == '' and line[1] in ['부', '절','편','강'] and 'num' in pd_l:
                ck_l.append('num')
            elif a == '' and line[1] not in ['부', '절','편','강'] and 'ara' not in pd_l :
                ck_l.append('ara')
                pd_l.append('ara') # 분류랑 숫자 결합
            elif a == '' and line[1] not in ['부', '절','편','강'] and 'ara' in pd_l:
                ck_l.append('ara')
        elif line[0].isnumeric() != True:   # 포함되는 리스트
            t = re.sub(r'[^a-zA-Z가-힣]','',line.lower())  # 기록 시에는 line을 기록해야 함
            b = ex.match(t)
            if b and b.group() not in pd_l:
                pd_l.append(b.group())
                ck_l.append(b.group())
            elif b and b.group() in pd_l:
                ck_l.append(b.group())
                pass
            else:
                pd_l.append('check')
                
    return pd_l, ck_l

# %%
# def clear_idx(isbn, tit, text, i, ex):
#     code = isbn[i] # isbn, main_title
#     title = tit[i]
# #     d1,d2,d3,d4 = 0,0,0,0  # 뎁스 채울 변수(초기화)
#     if '목차 더보기' in text: # 잘못 들어간 단어 삭제(틀 전체로 접근하다 보니 같이 달려옴)
#         text.remove('목차 더보기')
#     text = [clear_text(r) for r in text] # 이상한 문자 제거
#     text = [delete_text(r) for r in text]
#     pandan,ck_l = classification_list2(text,ex)
#     print(ck_l)
#     pandan = plus_pandan(pandan) 
#     if 'check' in pandan:  # 분류구분자에 예외 표현이 존재
#         isbn_ls.append(code)
#         main_title.append(title)
#         etc.append('check')
# #         print('check')
#         for ls in [depth_1, depth_2, depth_3, depth_4, pages]:
#             ls.append(np.NaN)
#     elif 'check' not in pandan:
#         if len(pandan) == 1:
# #             print('len1')
#             for num, line in enumerate(text):
#                 d,p = split_pn(line)
#                 depth_1.append(d)
#                 depth_2.append(np.NaN)
#                 depth_3.append(np.NaN)
#                 depth_4.append(np.NaN)
#                 etc.append(0) # 문제 없음
#                 pages.append(p)
#                 isbn_ls.append(code)
#                 main_title.append(title)
#         elif len(pandan) == 2:
#             idx_plus(pandan, text, code, title)
#         elif len(pandan) == 3:
#             idx_plus(pandan, text, code, title)
#         elif len(pandan) >= 4:
#             idx_plus(pandan, text, code, title)

# %%
def clear_idx(isbn, tit, text, i, ex):
    code = isbn[i] # isbn, main_title
    title = tit[i]
#     d1,d2,d3,d4 = 0,0,0,0  # 뎁스 채울 변수(초기화)
    if '목차 더보기' in text: # 잘못 들어간 단어 삭제(틀 전체로 접근하다 보니 같이 달려옴)
        text.remove('목차 더보기')
    text = [clear_text(r) for r in text] # 이상한 문자 제거
    text = [delete_text(r) for r in text]
    pandan,ck_l = classification_list2(text,ex)
    e = check_pandan(pandan, ck_l)
    print(e)
    pandan = plus_pandan(pandan) 
    if 'check' in pandan:  # 분류구분자에 예외 표현이 존재
        isbn_ls.append(code)
        main_title.append(title)
        etc.append('check')
#         print('check')
        for ls in [depth_1, depth_2, depth_3, depth_4, pages]:
            ls.append(np.NaN)
    elif 'check' not in pandan:
        if len(pandan) == 1:
#             print('len1')
            for num, line in enumerate(text):
                d,p = split_pn(line)
                depth_1.append(d)
                depth_2.append(np.NaN)
                depth_3.append(np.NaN)
                depth_4.append(np.NaN)
                etc.append(e) # 문제 없음
                pages.append(p)
                isbn_ls.append(code)
                main_title.append(title)
        elif len(pandan) == 2:
            idx_plus(pandan, text, code, title, e)
        elif len(pandan) == 3:
            idx_plus(pandan, text, code, title, e)
        elif len(pandan) >= 4:
            idx_plus(pandan, text, code, title,e)

# %%
def idx_plus(pandan, text, code, title,e):
    d1,d2,d3,d4 = '','','',''
    for num, line in enumerate(text):
        a = re.sub(r'[^(Ⅹ|Ⅸ|Ⅳ|Ⅴ?Ⅰ|Ⅱ|Ⅲ)]','', line) 
        d,p = split_pn(line) # d1인지 d2인지 아직 구별이 안됐으니 지역변수로
        if d[0].isnumeric() == True and d[1] in ['부', '절','편','강']: # 숫자분류
            check = 'num'
        elif d[0].isnumeric() == True  and d[1] not in ['부', '절','편','강'] and a == '': # 아라비아
            check = 'ara'
        elif d[0].isnumeric() == True and a != '': # roma
            check = 'roma'
        elif d[0].isnumeric() != True:
            b = re.sub(r'[^a-zA-Z가-힣]','',line.lower())
            b = ex.match(b)
            if b:
                check = b.group()
            else:
                pass
            
        if type(pandan[0]) == list:
            try:
                ii = pandan.index(check)
                if ii == 0:
                    d1 = d
                    d2,d3,d4 = '','',''
                elif ii == 1:
                    d2 = d
                    d3,d4 = '',''
                elif ii == 2:
                    d3 = d
                    d4 = ''
                else:   # 4뎁스 이후꺼 삭제시 이걸로 조절
                    d4 = d
            except:
                d1 = d
            for ls in [0,1,2,3]:
                d_append(ls,d1,d2,d3,d4)
            etc.append(e)
            pages.append(p)
            isbn_ls.append(code)
            main_title.append(title)
            
        elif type(pandan[1]) == list:  # 이부분 추가됨
            try:
                ii = pandan.index(check)
                if ii == 0:
                    d1 = d
                    d2,d3,d4 = '','',''
                elif ii == 1:
                    d2 = d
                    d3,d4 = '',''
                elif ii == 2:
                    d3 = d
                    d4 = ''
                else:   # 4뎁스 이후꺼 삭제시 이걸로 조절
                    d4 = d
            except:
                d2 = d
            for ls in [0,1,2,3]:
                d_append(ls,d1,d2,d3,d4)
            etc.append(e)
            pages.append(p)
            isbn_ls.append(code)
            main_title.append(title)
            
        else:
            print('store3')
            ii = pandan.index(check)
            ii = pandan.index(check)
            if ii == 0:
                d1 = d
                d2,d3,d4 = '','',''
            elif ii == 1:
                d2 = d
                d3,d4 = '',''
            elif ii == 2:
                d3 = d
                d4 = ''
            else:   # 4뎁스 이후꺼 삭제시 이걸로 조절
                d4 = d
            for ls in [0,1,2,3]:
                d_append(ls,d1,d2,d3,d4)
            etc.append(e)
            pages.append(p)
            isbn_ls.append(code)
            main_title.append(title)
        print(d1,d2,d3,d4,'store')
#         store(pandan, check, d, p, code, title,d1,d2,d3,d4) # if_else문으로 check를 받고 시행하려고

# %%
# def idx_plus(pandan, text, code, title):
#     d1,d2,d3,d4 = '','','',''
#     for num, line in enumerate(text):
#         a = re.sub(r'[^(Ⅹ|Ⅸ|Ⅳ|Ⅴ?Ⅰ|Ⅱ|Ⅲ)]','', line) 
#         d,p = split_pn(line) # d1인지 d2인지 아직 구별이 안됐으니 지역변수로
#         if d[0].isnumeric() == True and d[1] in ['부', '절','편','강']: # 숫자분류
#             check = 'num'
#         elif d[0].isnumeric() == True  and d[1] not in ['부', '절','편','강'] and a == '': # 아라비아
#             check = 'ara'
#         elif d[0].isnumeric() == True and a != '': # roma
#             check = 'roma'
#         elif d[0].isnumeric() != True:
#             b = re.sub(r'[^a-zA-Z가-힣]','',line.lower())
#             b = ex.match(b)
#             if b:
#                 check = b.group()
#             else:
#                 pass
            
#         if type(pandan[0]) == list:
#             try:
#                 ii = pandan.index(check)
#                 if ii == 0:
#                     d1 = d
#                     d2,d3,d4 = '','',''
#                 elif ii == 1:
#                     d2 = d
#                     d3,d4 = '',''
#                 elif ii == 2:
#                     d3 = d
#                     d4 = ''
#                 else:   # 4뎁스 이후꺼 삭제시 이걸로 조절
#                     d4 = d
#             except:
#                 d1 = d
#             for ls in [0,1,2,3]:
#                 d_append(ls,d1,d2,d3,d4)
#             etc.append(0)
#             pages.append(p)
#             isbn_ls.append(code)
#             main_title.append(title)
            
#         elif type(pandan[1]) == list:  # 이부분 추가됨
#             try:
#                 ii = pandan.index(check)
#                 if ii == 0:
#                     d1 = d
#                     d2,d3,d4 = '','',''
#                 elif ii == 1:
#                     d2 = d
#                     d3,d4 = '',''
#                 elif ii == 2:
#                     d3 = d
#                     d4 = ''
#                 else:   # 4뎁스 이후꺼 삭제시 이걸로 조절
#                     d4 = d
#             except:
#                 d2 = d
#             for ls in [0,1,2,3]:
#                 d_append(ls,d1,d2,d3,d4)
#             etc.append(0)
#             pages.append(p)
#             isbn_ls.append(code)
#             main_title.append(title)
            
#         else:
#             print('store3')
#             ii = pandan.index(check)
#             ii = pandan.index(check)
#             if ii == 0:
#                 d1 = d
#                 d2,d3,d4 = '','',''
#             elif ii == 1:
#                 d2 = d
#                 d3,d4 = '',''
#             elif ii == 2:
#                 d3 = d
#                 d4 = ''
#             else:   # 4뎁스 이후꺼 삭제시 이걸로 조절
#                 d4 = d
#             for ls in [0,1,2,3]:
#                 d_append(ls,d1,d2,d3,d4)
#             etc.append(0)
#             pages.append(p)
#             isbn_ls.append(code)
#             main_title.append(title)
#         print(d1,d2,d3,d4,'store')
# #         store(pandan, check, d, p, code, title,d1,d2,d3,d4) # if_else문으로 check를 받고 시행하려고

# %%
def d_append(ls,d1,d2,d3,d4):
    if ls == 0:
        depth_dict[f'{ls}'].append(d1)
    elif ls == 1:
        depth_dict[f'{ls}'].append(d2)
    elif ls == 2:
        depth_dict[f'{ls}'].append(d3)
    elif ls == 3:
        depth_dict[f'{ls}'].append(d4)
    print('d_append')

# %% [markdown]
# # making

# %%
def check_pandan(pd_l, ck_l):
    if len(pd_l) == 1:
        e = 0
    else:
        print('cp on')
        check = ''.join(ck_l).split(pd_l[0])
        pp = ''.join(pd_l[1:])
        if len(check) == 2:
            e = 0
        elif len(check) >= 3:
            if check[1][:len(pp)] == check[2][:len(pp)]:
                e = 0 # 문제 없음
            elif check[1][:len(pp)] != check[2][:len(pp)]:
                e = 'd_check'
            else:
                e = 3 # 구분주려고 임시
                print('???checkpandan')
        elif len(check) == 1:
            e = 2
        else:
            e = 3 # 구분주려고 임시
            print('??checkpandan')
    return e

# %% [markdown]
# # data loading & variable

# %%
# data  police_book_idx_unique
data = pd.read_excel("C:\police_data\index_one_book.xlsx")
# 변수 설정
isbn, tit, text = data['isbn'], data['main_title'], data['index']

# 저장될 리스트
isbn_ls, main_title, depth_1, depth_2, depth_3, depth_4, etc, pages = [],[],[],[],[],[],[],[]

# depth정보를 저장할 변수
d1,d2,d3,d4 = '','','',''
# 구분자 리스트
pandan = []
# 구분자, 교재명
check, title = '',''
# isbn, 페이지
code, p = 0,0

# %%
# 지정 구분자
ex = re.compile("제절|제편|제강|제항|제장|제회|제부|제과|제관|강|목|장|항|회|부|사례|총론|형법총론|헌법총론|각론|형법각론|헌법각론|부록|키워드|최근|실전|모의|문제|정답|해설|차례|전범위|기출|참고|판례|핵심|part|chapter|day|section|theme|case|keyword|point|q|question|contents")

# %%
# 일부 가지고 테스트
depth_dict = {'0':depth_1,'1':depth_2,'2':depth_3,'3':depth_4}
d_dict = {'0':d1,'1':d2,'2':d3,'3':d4} 
# 실행
for i in range(10):
    try:
        tet = make_ls(text, i)
        clear_idx(isbn, tit, tet, i, ex)
    except:
#         print('i')
        isbn_ls.append(isbn[i])
        main_title.append(tit[i])
        etc.append(2)  # 데이터가 존재하지 않는 경우
        for k in [depth_1, depth_2,depth_3,depth_4,pages]:
            k.append(np.NaN)
# Out:
# cp on
# d_check
# cp on
# 0
# cp on
# 0
# cp on
# 0
# cp on
# 0
# 0
# cp on
# 0
# cp on
# d_check
# cp on
# d_check
# cp on
# 0

# %%
# 편한 저장을 위해 딕셔너리
depth_dict = {'0':depth_1,'1':depth_2,'2':depth_3,'3':depth_4}
d_dict = {'0':d1,'1':d2,'2':d3,'3':d4} 
# 실행
for i in range(len(text)):
    try:
        tet = make_ls(text, i)
        clear_idx(isbn, tit, tet, i, ex)
    except:
#         print('i')
        isbn_ls.append(isbn[i])
        main_title.append(tit[i])
        etc.append(2)  # 데이터가 존재하지 않는 경우
        for k in [depth_1, depth_2,depth_3,depth_4,pages]:
            k.append(np.NaN)
# Out:
# cp on
# d_check
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론    store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학   store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제1절 헌법의 의의  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제1절 헌법의 의의 제1항 헌법의 개념과 분류 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제1절 헌법의 의의 제2항 헌법의 특성 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제2절 헌법학 연구  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제2절 헌법학 연구 제1항 헌법의 해석 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제2절 헌법학 연구 제2항 헌법관 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제3절 헌법의 제정  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제4절 헌법의 개정  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제5절 헌법의 변천  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제1장 헌법과 헌법학 제6절 헌법의 수호  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설   store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제1절 대한민국헌정사  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제2절 대한민국의 국가형태  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제3절 대한민국의 구성요소  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제1항 한국헌법의 전문 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제2항 국민주권의 원리 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제3항 민주주의의 원리 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제4항 법치주의의 원리 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제5항 사회국가의 원리 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제6항 문화국가의 원리 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제4절 한국헌법의 기본원리 제7항 평화국가의 원리 store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제5절 정당제도  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제6절 선거제도  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제7절 공무원제도  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제1편 헌법총론 제2장 대한민국헌법총설 제8절 지방자치제도  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 기본권론    store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 기본권론 제1장 기본권 총론   store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 기본권론 제1장 기본권 총론 
store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 수사 제2장 수사의 개시 제3절 압수ㆍ수색ㆍ검증  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 수사 제2장 수사의 개시 제4절 판사에 의한 강제처분  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 수사 제3장 수사의 종결   store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 수사 제3장 수사의 종결 제1절 검사의 수사의 종결  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 수사 제3장 수사의 종결 제2절 불기소처분에 대한 불복  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제2편 수사 제3장 수사의 종결 제3절 공소제기 후의 수사  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거    store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제1절 증거의 의의와 종류  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제2절 증명의 기본원칙  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제3절 자백배제법칙  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제4절 위법수집증거배제법칙  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제5절 전문법칙 傳聞法則  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제6절 증거동의  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제7절 탄핵증거  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제8절 자백의 보강법칙  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제9절 공판조서의 증명력  store
# store3
# d_append
# d_append
# d_append
# d_append
# 제3편 증거  제9절 공판조서의 증명력 부록 공수처법 store

# %%
len(main_title), len(depth_1)
# Out:
# (8324, 8324)

# %%
df_ls = pd.DataFrame({'isbn':isbn_ls, 'main_title':main_title,'depth_1':depth_1, 'depth_2':depth_2,\
                      'depth_3':depth_3, 'depth_4': depth_4,'pages':pages,'etc':etc})

# %%
df_ls.to_excel('C:/police_data/06_30_test1.xlsx',encoding = 'utf-8-sig', index=False)
# Out:
# C:\Data\conda\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
df_ls.loc[:,'depth_2'].unique()
# Out:
# array(['', '제1장 헌법과 헌법학', '제2장 대한민국헌법총설', ..., '제1장 형사소송법의 기초',
#        '제2장 형사소송법의 기본이념', '제1장 수사의 기초'], dtype=object)

# %%
df_ls
# Out:
#                isbn                              main_title   depth_1  \
# 0     9791166184604                       2023 경찰 헌법집중 기출해설  제1편 헌법총론
# 1     9791166184604                       2023 경찰 헌법집중 기출해설  제1편 헌법총론
# 2     9791166184604                       2023 경찰 헌법집중 기출해설  제1편 헌법총론
# 3     9791166184604                       2023 경찰 헌법집중 기출해설  제1편 헌법총론
# 4     9791166184604                       2023 경찰 헌법집중 기출해설  제1편 헌법총론
# ...             ...                                     ...       ...
# 8319  9791168808720  2023 해커스경찰 갓대환 형사법 기본서 2: 형사소송법 수사와 증거    제3편 증거
# 8320  9791168808720  2023 해커스경찰 갓대환 형사법 기본서 2: 형사소송법 수사와 증거    제3편 증거
# 8321  9791168808720  2023 해커스경찰 갓대환 형사법 기본서 2: 형사소송법 수사와 증거    제3편 증거
# 8322  9791168808720  2023 해커스경찰 갓대환 형사법 기본서 2: 형사소송법 수사와 증거    제3편 증거
# 8323  9791168808720  2023 해커스경찰 갓대환 형사법 기본서 2: 형사소송법 수사와 증거    제3편 증거
#
#           depth_2        depth_3         depth_4 pages      etc
# 0                                                  NaN  d_check
# 1     제1장 헌법과 헌법학                                    2  d_check
# 2     제1장 헌법과 헌법학     제1절 헌법의 의의                     2  d_check
# 3     제1장 헌법과 헌법학     제1절 헌법의 의의  제1항 헌법의 개념과 분류     3  d_check
# 4     제1장 헌법과 헌법학     제1절 헌법의 의의      제2항 헌법의 특성     6  d_check
# ...           ...            ...             ...   ...      ...
# 8319                    제6절 증거동의                   NaN        0
# 8320                    제7절 탄핵증거                   NaN        0
# 8321                제8절 자백의 보강법칙                   NaN        0
# 8322               제9절 공판조서의 증명력                   NaN        0
# 8323               제9절 공판조서의 증명력         부록 공수처법   NaN        0
#
# [8324 rows x 8 columns]
