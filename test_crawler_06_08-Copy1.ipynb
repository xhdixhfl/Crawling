# %% [markdown]
# # setting
# - 전문 서점 부분 제외 ver

# %%
# 필수 라이브러리 로딩
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains # 스크롤
from urllib import request # 이미지
import csv
import time

import numpy as np # 결측값 삽입용
import re # 정규표현식
import pandas as pd

# %%
## 교재 테이블 리스트들 
main_title = []  # 본제
sub_title = []  # 부제
author = []  # 저자
publish = []  # 출판
date = []  # 발행일
cate = []  # 네이버 카테고리
tot_page = []  # 전체 쪽수
size = []  # 크기
wei = []  # 무게
img = [] # 이미지
book_info = []  # 책소개
book_review = []  # 책서평
kobo_cate = []
title_isbn = [] # isbn 교재명
set_isbn = [] #set
isbn = []
book_type = [] #제본
ver = []  # 판정보
last_ver = []  # 이전 판 정보
keyword = []  # 키워드
price = []

index = []
idx_page = []

# %% [markdown]
# # 바꾼 부분

# %%
# # 함수 정의
# def page(text,ls):
#     x = text.split(' ')
#     try:
#         if x[-1].isnumeric() == True:
#             ls.append(x[-1]) # sub_p
#         else:
#             ls.append(np.NaN)
#     except:
#         ls.append(np.NaN)

# def naver():
#     # 창 전환
#     driver.switch_to.window(driver.window_handles[1]) 
#     time.sleep(3)
#     try: # 제목 수집
#         main_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_book_name__JuBQ2').text) # 본
#         sub_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_sub_title__B0uMS').text) # 부
#     except:
#         main_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_title_area__fspvB').text) #부제랑 안나눠졌을시
#         sub_title.append(np.NaN)
    
#     # 저자, 출판, 발행일 수집
#     info = driver.find_elements(By.CLASS_NAME, "bookTitle_inner_content__REoK1")
#     author.append(info[0].text) # 저자
#     publish.append(info[1].text) # 출판
#     date.append(info[2].text) # 발행일

#     # 책정보(카테고리, 쪽수, 무게 크기, ISBN) 수집
#     sub1 = driver.find_elements(By.CLASS_NAME, "bookBasicInfo_info_detail__I0Fx5") # 카테고리, ISBN
#     sub2 = driver.find_elements(By.CLASS_NAME, "bookBasicInfo_spec__qmQ_N") # 쪽수, 크기(무게)
#     # cate
#     cate.append(sub1[0].text)
#     # code
#     code = sub1[2].text
# #     isbn.append(code) 뒤에 isbn정보 수집떄 어펜드 하기
#     # page
#     if len(sub2) == 3:
#         tot_page.append(sub2[0].text)
#         # wei
#         wei.append(sub2[1].text)
#         # size
#         size.append(sub2[2].text)
#     elif len(sub2) == 2:
#         tot_page.append(sub2[0].text)
#         # wei
#         wei.append(np.nan)
#         # size
#         size.append(sub2[-1].text)
#     elif len(sub2) == 1:
#         tot_page.append(sub2[0].text)
#         wei.append(np.nan)
#         size.append(np.nan)
#     else:
#         tot_page.append(np.nan)
#         wei.append(np.nan)
#         size.append(np.nan)
        
#     # image
#     img_url = driver.find_element(By.XPATH, '//*[@id="container"]/div[2]/div[1]/div[1]/div[1]/div[1]/div/img').get_attribute("src")
#     time.sleep(2)
#     request.urlretrieve(img_url,f"C:\\police_img\\{code}.jpg")
#     img.append(f'{code}.jpg')
#     # 소개
#     try:
#         text = driver.find_element(By.XPATH, '//*[@id="book_section-info"]/div[3]/div[2]/div[1]').text.split('\n')
#         text = [t for t in text if t != '' ]
#         book_info.append(text)
#     except:
#         book_info.append(np.NaN)
#     scroll = driver.find_element(By.PARTIAL_LINK_TEXT,'목차')
# # somthing element까지 스크롤
#     act = ActionChains(driver)  # 수정한 부분
#     act.move_to_element(scroll).perform()
#     scroll.click()     # 수정한 부분
#     time.sleep(2)
#     tee = driver.find_element(By.CSS_SELECTOR, '#book_section-info > div:nth-child(5) > div.infoItem_data_box__VwBf3.infoItem_expand__xBsGl > div.infoItem_data_text__bUgVI').text
#     txts = tee.split('\n')
#     txts = [t for t in txts if t != '']
#     for t in txts:
#         page(t, idx_page)
#         index.append(t)
        
#     return code

# %%
# 함수 정의
def page(text,ls):
    t_ls = []
    x = text.split(' ')
    try:
        if x[-1].isnumeric() == True:
            t_ls.append(x[-1]) # sub_p
        else:
            t_ls.append(np.NaN)
    except:
        t_ls.append(np.NaN)
    ls.append(t_ls)

def naver():
    # 창 전환
    driver.switch_to.window(driver.window_handles[1]) 
    time.sleep(2)
    try: # 제목 수집
        main_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_book_name__JuBQ2').text) # 본
        sub_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_sub_title__B0uMS').text) # 부
    except:
        main_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_title_area__fspvB').text) #부제랑 안나눠졌을시
        sub_title.append(np.NaN)
    
    # 저자, 출판, 발행일 수집
    time.sleep(1)
    try:
        info_func()
    except:
        for x in [author, publish, date]:
            x.append(np.NaN)
    
    try:
        code = sub1_func()
    except:
        print('sub1함수 예외상황')
    
    try:
        sub2_func()
    except:
        print('sub2함수 예외상황')
    
    try:
        img_func(code)
    except:
        img.append(np.nan)
    # 소개
    try:
        text = driver.find_element(By.XPATH, '//*[@id="book_section-info"]/div[3]/div[2]/div[1]').text.split('\n')
        text = [t for t in text if t != '' ]
        book_info.append(text)
    except:
        book_info.append(np.NaN)
        
    idx_func() 
    return code

# %%
def info_func():
    info = driver.find_elements(By.CLASS_NAME, "bookTitle_inner_content__REoK1")
    author.append(info[0].text) # 저자
    publish.append(info[1].text) # 출판
    date.append(info[2].text) # 발행일
    
def sub1_func():
    sub1 = driver.find_elements(By.CLASS_NAME, "bookBasicInfo_info_detail__I0Fx5") # 카테고리, ISBN
    # cate
    cate.append(sub1[0].text)
    # code
    code = sub1[2].text
    return code

def sub2_func():
    sub2 = driver.find_elements(By.CLASS_NAME, "bookBasicInfo_spec__qmQ_N") # 쪽수, 크기(무게)
    if len(sub2) == 3:
        tot_page.append(sub2[0].text)
        # wei
        wei.append(sub2[1].text)
        # size
        size.append(sub2[2].text)
    elif len(sub2) == 2:
        tot_page.append(sub2[0].text)
        # wei
        wei.append(np.NaN)
        # size
        size.append(sub2[1].text)
    elif len(sub2) == 1:
        tot_page.append(sub2[0].text)
        wei.append(np.NaN)
        size.append(np.NaN)
    else:
        tot_page.append(np.NaN)
        wei.append(np.NaN)
        size.append(np.NaN)
        
def img_func(code):
    # image
    img_url = driver.find_element(By.XPATH, '//*[@id="container"]/div[2]/div[1]/div[1]/div[1]/div[1]/div/img').get_attribute("src")
    time.sleep(2)
    request.urlretrieve(img_url,f"C:\\police_img\\{code}.jpg")
    img.append(f'{code}.jpg')
    
def idx_func():
    scroll = driver.find_element(By.PARTIAL_LINK_TEXT,'목차')
# somthing element까지 스크롤
    act = ActionChains(driver)  # 수정한 부분
    act.move_to_element(scroll).perform()
    scroll.click()     # 수정한 부분
    time.sleep(2)
    try: 
        tee = driver.find_element(By.CSS_SELECTOR, '#book_section-info > div:nth-child(5) > div.infoItem_data_box__VwBf3.infoItem_expand__xBsGl > div.infoItem_data_text__bUgVI').text
        txts = tee.split('\n')
        txts = [t for t in txts if t != '']
        for t in txts:
            page(t, idx_page)
        index.append(txts)
    except:
        index.append(np.NaN)
        idx_page(np.NaN)

# %%
def idx_func():
    scroll = driver.find_element(By.PARTIAL_LINK_TEXT,'목차')
# somthing element까지 스크롤
    act = ActionChains(driver)  # 수정한 부분
    act.move_to_element(scroll).perform()
    scroll.click()     # 수정한 부분
    time.sleep(2)
    try: 
        ex = driver.find_elements(By.CLASS_NAME,'infoItem_data_text__bUgVI')
        txts = ex[-1].split('\n')
        txts = [t for t in txts if t != '']
        for t in txts:
            page(t, idx_page)
        index.append(txts)
    except:
        index.append(np.NaN)
        idx_page(np.NaN)

# %% [markdown]
# - ISBN은 세트랑 세트가 아닌것이 불리되어야 하니깐, 해당페이지 들어가자 마자
# resultData의 개수를 카운트해서 하나면 단일 하나 이상이면 세트 권으로 파악을 하자
# re.sub(r'[^0-9]', '', string)

# %%
def one_isbn():
    # 가격
    pr = driver.find_element(By.XPATH, '//*[@id="resultList_div"]/form/div/div/div/ul/li[6]').text
    price.append(pr.split(' ')[-1])
    driver.find_element(By.XPATH, f'//*[@id="resultList_div"]/form/div[{1}]/div/div/div/a').click()
    time.sleep(3)
    num = driver.find_elements(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li/div')
    print(len(num))
    if len(num) == 11: 
    # title
        title_isbn.append(driver.find_element(By.CSS_SELECTOR,\
                                              '#contents > div > div.resultViewDetail > div.tit').text)
        # 단일코드
        one = driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[1]/div').text
        print(one)
        isbn.append(re.sub(r'[^0-9]', '', one.split(' ')[0]))
        # 제본
        book_type.append(driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[3]/div').text)
        # 판정보
        ver.append(driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[4]/div').text)
        # 이전판 정보
        last = driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[5]/div').text
        last_ver.append(re.sub(r'[^0-9]', '', last.split(' ')[-1]))
        # 키워드
        keyword.append(driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[11]/div').text)
        # 세트 코드
        set_isbn.append(np.NaN)
    else:
        title_isbn.append(driver.find_element(By.CSS_SELECTOR,\
                                              '#contents > div > div.resultViewDetail > div.tit').text)
        # 단일코드
        one = driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[1]/div').text
        isbn.append(re.sub(r'[^0-9]', '', one.split(' ')[0]))
        set_isbn.append(np.NaN)
        for x in [book_type, ver, last_ver, keyword]:
            x.append(np.NaN)
    # //*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[2]/strong
    driver.close() # 종료
    time.sleep(1)
    driver.switch_to.window(driver.window_handles[0])  # 다시 본화면 전환

# %%
def set_code(code):
    # 가격
    prs = driver.find_elements(By.CLASS_NAME, 'dot-list')
    for i in range(len(prs), 0, -1):
        # 상품 선택
        driver.find_element(By.XPATH, f'//*[@id="resultList_div"]/form/div[{i}]/div/div/div/a').click()
        time.sleep(3)
        # 안에 정보 수 세기
        num = driver.find_elements(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li/div')
        if len(num) != 12: # 세트 권( 바로 앞에서 네이버 정보를 수집해서 따로 더할 필요 없)
            price.append(prs[-1].text.split(' ')[-1])
            title_isbn.append(driver.find_element(By.CSS_SELECTOR,\
                                              '#contents > div > div.resultViewDetail > div.tit').text)
            isbn.append(code)
            set_isbn.append(code)
            for x in [book_type, ver, last_ver, keyword]:
                x.append(np.NaN) # 나머지 항목들은 널값처리
        else:
            one = driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[1]/div').text
            isbn_code.append(re.sub(r'[^0-9]', '', one.split(' ')[0]))
#             s = driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[2]/div').text
            set_isbn.append(code)  # 네이버에서 수집한거
            title_isbn.append(driver.find_element(By.CSS_SELECTOR,\
                                              '#contents > div > div.resultViewDetail > div.tit').text)
        # 제본
            book_type.append(driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[4]/div').text)
            # 판정보
            ver.append(driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[5]/div').text)
            # 이전판 정보
            last = driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[6]/div').text
            last_ver.append(re.sub(r'[^0-9]', '', last.split(' ')[-1]))
            # 키워드
            keyword.append(driver.find_element(By.XPATH, '//*[@id="contents"]/div/div[1]/div[2]/div[2]/ul/li[12]/div').text)
            # 가격 외 기타 정보 널값
            for x in [price,main_title, sub_title, author,publish,date,cate,tot_page, wei, size,\
                      img, book_info, index, idx_page]:
                x.append(np.NaN)
            time.sleep(3)
        driver.back()  
        
    driver.close() # 종료
    driver.switch_to.window(driver.window_handles[0])  # 다시 본화면 전환

# %%
def search_isbn(code): 
    driver.get(f'https://www.nl.go.kr/seoji/contents/S80100000000.do?schType=simple&schStr={code}')
    time.sleep(3)
    num = driver.find_elements(By.CLASS_NAME, 'resultData')
    if len(num) == 1: # 단일 경우 함수
        one_isbn()
    else:
        set_code(code)

# %%
# 첫화면
URL = 'https://search.shopping.naver.com/book/search/category?bookTabType=ALL&catId=50005981&pageIndex=1&pageSize=40&sort=DATE'
ops = webdriver.ChromeOptions()
ops.add_experimental_option('excludeSwitches', ['enable-logging'])

sv = Service(executable_path= 'C:\Data\chromedriver')
driver = webdriver.Chrome(service=sv, options=ops)

driver.get(url=URL)

# %%
global n
n = 2

def find():
    # 상품 찾는 함수
    tag = driver.find_element(By.CLASS_NAME,'style_footer__DaTQt')
# somthing element까지 스크롤
    action = ActionChains(driver)
    action.move_to_element(tag).perform()
    time.sleep(3)
    try:
        elements = driver.find_elements(By.CLASS_NAME,f'bookListItem_vendor__d_xBD')
        print(len(elements),"상품수")
        for i,ele in enumerate(elements):
            print(i, ele.text)
            ele.click()
            time.sleep(2)
            print('상품클릭')
            # 네이버 함수
            isbn = naver()
            print(isbn)
            search_isbn(isbn)
    except:
        print("find예외")
        pass

# # 페이지 넘김
# def action(n):
# #     driver.get(url=URL)
#     find()
#     try:
#         driver.find_element(By.LINK_TEXT,f'{n}').click()
#         n += 1
#         return action(n)
        
#     except:
#         driver.close()

# %%
try:
    for n in range(2,50):
        print(f'{n-1}페이지')
        find()
        time.sleep(2)
        print('for문 페이지 클릭전')
        driver.find_element(By.LINK_TEXT,f'{n}').click()
        print('for문 페이지 클릭후')
        time.sleep(3)
except:
    driver.close()
# Out:
# 1페이지
# 3
# 0 판매처 43
# 상품클릭
# 9791166184604
# 11
# 979-11-6618-460-4 (13360)
# 1 판매처 16
# 상품클릭
# 9791197865367
# 8
# 2 판매처 26
# 상품클릭
# 9791167930927
# 9
# for문 페이지 클릭전
# for문 페이지 클릭후
# 2페이지
# 0
# for문 페이지 클릭전
# for문 페이지 클릭후
# 3페이지
# 1
# 0 판매처 15
# 상품클릭
# find예외
# for문 페이지 클릭전

# %%
test3 = pd.DataFrame({'main_title': main_title, 'sub_title':sub_title,'author':author,'publish':publish,\
                        'date':date,'cate':cate, 'tot_page':tot_page,'size':size, 'wei':wei,\
                         'img':img, 'book_info':book_info,\
                         'set_isbn':set_isbn, 'isbn':isbn,'title_isbn':title_isbn,'price':price,\
                    'book_type':book_type, 'ver':ver,'last_ver':last_ver,'keyword':keyword})
test3.to_excel('C:/police_data/test3.xlsx',encoding = 'utf-8-sig', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 test3 = pd.DataFrame({'main_title': main_title, 'sub_title':sub_title,'author':author,'publish':publish,\
#       2                         'date':date,'cate':cate, 'tot_page':tot_page,'size':size, 'wei':wei,\
#       3                          'img':img, 'book_info':book_info,\
#       4                          'set_isbn':set_isbn, 'isbn':isbn,'title_isbn':title_isbn,'price':price,\
#       5                     'book_type':book_type, 'ver':ver,'last_ver':last_ver,'keyword':keyword})
#       6 test3.to_excel('C:/police_data/test3.xlsx',encoding = 'utf-8-sig', index=False)
#
# File C:\Data\conda\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File C:\Data\conda\lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File C:\Data\conda\lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File C:\Data\conda\lib\site-packages\pandas\core\internals\construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
tot_page

# %%
len(book_info)

# %%
len(idx_page)

# %%
index

# %%
size, wei
# Out:
# (['190*260*16mm', '188*257*30mm', '215*297*20mm', '188*257*20mm'],
#  ['737g', '0g', '0g', '0g'])

# %%
# elements = driver.find_elements(By.CLASS_NAME,f'bookListItem_vendor__d_xBD')
# len(elements)

# %%
isbn
# Out:
# ['9791166184604', '9791197865367', '9791167930927']

# %% [markdown]
# ## 오류 찾기

# %%
URL = 'https://search.shopping.naver.com/book/catalog/40464414622?NaPm=ct%3Dlimwblpk%7Cci%3D5589478e77a87cd16ba45487e1e9ac0c64f2e12d%7Ctr%3Dboksl%7Csn%3D95694%7Chk%3D2faf63dd0467f5f01a5526e9560cac4a0b719804'
ops = webdriver.ChromeOptions()
ops.add_experimental_option('excludeSwitches', ['enable-logging'])

sv = Service(executable_path= 'C:\Data\chromedriver')
driver = webdriver.Chrome(service=sv, options=ops)

driver.get(url=URL)

# %%
try: # 제목 수집
    main_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_book_name__JuBQ2').text) # 본
    sub_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_sub_title__B0uMS').text) # 부
except:
    main_title.append(driver.find_element(By.CLASS_NAME,f'bookTitle_title_area__fspvB').text) #부제랑 안나눠졌을시
    sub_title.append(np.NaN)
    
    # 저자, 출판, 발행일 수집
time.sleep(1)
try:
    info_func()
except:
    for x in [author, publish, date]:
        x.append(np.NaN)
    
try:
    code = sub1_func()
except:
    print('sub1함수 예외상황')
    
try:
    sub2_func()
except:
    print('sub2함수 예외상황')
    
try:
    img_func(code)
except:
    img.append(np.nan)
    # 소개
try:
    text = driver.find_element(By.XPATH, '//*[@id="book_section-info"]/div[3]/div[2]/div[1]').text.split('\n')
    text = [t for t in text if t != '' ]
    book_info.append(text)
except:
    book_info.append(np.NaN)
        
idx_func() 
print(code)

#book_section-info > div:nth-child(4) > div.infoItem_data_box__VwBf3.infoItem_expand__xBsGl > a
#book_section-info > div:nth-child(4) > div.infoItem_data_box__VwBf3.infoItem_expand__xBsGl > div.infoItem_data_text__bUgVI
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 53, in idx_func()
#      52 try:
# ---> 53     tee = driver.find_element(By.CSS_SELECTOR, '#book_section-info > div:nth-child(5) > div.infoItem_data_box__VwBf3.infoItem_expand__xBsGl > div.infoItem_data_text__bUgVI').text
#      54     txts = tee.split('\n')
#
# File C:\Data\conda\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\Data\conda\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#
# File C:\Data\conda\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#book_section-info > div:nth-child(5) > div.infoItem_data_box__VwBf3.infoItem_expand__xBsGl > div.infoItem_data_text__bUgVI"}
#   (Session info: chrome=114.0.5735.110)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0103A813+48355]
# 	(No symbol) [0x00FCC4B1]
# 	(No symbol) [0x00ED5358]
# 	(No symbol) [0x00F009A5]
# 	(No symbol) [0x00F00B3B]
# 	(No symbol) [0x00F2E232]
# 	(No symbol) [0x00F1A784]
# 	(No symbol) [0x00F2C922]
# 	(No symbol) [0x00F1A536]
# 	(No symbol) [0x00EF82DC]
# 	(No symbol) [0x00EF93DD]
# 	GetHandleVerifier [0x0129AABD+2539405]
# 	GetHandleVerifier [0x012DA78F+2800735]
# 	GetHandleVerifier [0x012D456C+2775612]
# 	GetHandleVerifier [0x010C51E0+616112]
# 	(No symbol) [0x00FD5F8C]
# 	(No symbol) [0x00FD2328]
# 	(No symbol) [0x00FD240B]
# 	(No symbol) [0x00FC4FF7]
# 	BaseThreadInitThunk [0x76297D59+25]
# 	RtlInitializeExceptionChain [0x77B0B74B+107]
# 	RtlClearBits [0x77B0B6CF+191]
#
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 38
#      35 except:
#      36     book_info.append(np.NaN)
# ---> 38 idx_func()
#      39 print(code)
#
# Cell In[5], line 61, in idx_func()
#      59 except:
#      60     index.append(np.NaN)
# ---> 61     idx_page(np.NaN)
#
# TypeError: 'list' object is not callable

# %%
scroll = driver.find_element(By.PARTIAL_LINK_TEXT,'목차')
# somthing element까지 스크롤
act = ActionChains(driver)  # 수정한 부분
act.move_to_element(scroll).perform()
scroll.click()     # 수정한 부분
time.sleep(2)
print(scroll.location)

ex = driver.find_elements(By.CLASS_NAME,'infoItem_data_text__bUgVI')
ex[-1]
# Out:
# {'x': 133, 'y': 1940}
